# %% [markdown]
# <a href="https://colab.research.google.com/github/nour-ezzehi/Travail-des-Femmes-Agricultrices/blob/main/Agricultrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("sample_data/Cleaned SST en agriculture.csv")
df.head()
df.columns
# Out:
# Index(['N°', 'Date de la visite', 'Nom', 'Prénom', 'N° du téléphone',
#        'Date de naissance', 'Age', 'Situation maritale', 'Nb enfants',
#        'Nb pers à charge', 'Profession du mari', 'Domicile',
#        'Niveau socio-économique', 'Tabagisme', 'Neffa', 'Fumées de Tabouna',
#        'Antécédents familiaux', 'q', 'Antécédent personnels: chirurgicaux',
#        'AT en milieu agricole', 'H travail / jour', 'Mécanisme AT',
#        'Ménopause', 'Age ménopause', 'Antécédents gynéco',
#        'Ancienneté agricole', 'Produits chimiques utilisés',
#        'Troubles gynécologiques', 'Professions antérieures',
#        'Catégorie professionnelle', 'Statut', 'Tâches effectuées',
#        'Contraintes physiques', 'Engrais utilisés',
#        'Produits biologiques utilisés', 'Contraintes thermiques',
#        'J travail / Sem', 'Masque pour pesticides', 'Bottes',
#        'Niveau scolaire', 'Gants', 'Casquette/Mdhalla', 'Manteau imperméable',
#        'Moyen de transport', 'Troubles cardio-respiratoires',
#        'Troubles cognitifs', 'Troubles neurologiques',
#        'Troubles cutanés/phanères', 'Autres plaintes:', 'Poids', 'Taille',
#        'TAS', 'TAD', 'GAD', 'Examen cardiovasculaire et pulmonaire',
#        'Examen tête et cou', 'Examen buccodentaire',
#        'Examen des membres supérieurs', 'Examen du rachis',
#        'Examen des téguments', 'Examen neurologique', 'Examen abdominal',
#        'Examen visuel', 'Spirométrie', 'Interprétation Spiro'],
#       dtype='object')

# %% [markdown]
# Exploratory Analysis

# %%
columns_to_drop = ['N°' ,'Nom', 'Prénom', 'N° du téléphone', 'Date de la visite', 'Date de naissance', 'Age ménopause', 'Antécédents gynéco', 'Niveau scolaire']
df.drop(columns=columns_to_drop, inplace=True)
print(df['Situation maritale'].unique())
# Apply feature engineering to the 'Situation maritale' column
df['Situation maritale'] = df['Situation maritale'].apply(lambda x: 1 if x == 'mariée' else 0)
#treat missing values in the age column
#df['Age'].isna().sum()
# Treat missing values in 'Age' column
df['Age'] = df['Age'].replace({"non spécifié": np.nan, "": np.nan})  # Handle missing values
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')  # Convert to numeric
df['Age'] = df['Age'].fillna(df['Age'].mean()).astype(int)  # Fill missing with mean & convert to int

# Ensure 'Nb enfants' is numeric and handle missing values
df['Nb enfants'] = df['Nb enfants'].replace("non spécifié", np.nan)
df['Nb enfants'] = pd.to_numeric(df['Nb enfants'], errors='coerce').fillna(0).astype(int)
# Treat 'Nb pers à charge' column
df['Nb pers à charge'] = df['Nb pers à charge'].replace("non spécifié", np.nan)  # Handle missing
df['Nb pers à charge'] = pd.to_numeric(df['Nb pers à charge'], errors='coerce')  # Convert to numeric
df['Nb pers à charge'] = df['Nb pers à charge'].fillna(df['Nb pers à charge'].mean()).astype(int)  # Fill missing with mean
# Conditionally update 'Nb pers à charge' only when 'Nb enfants' is greater
df['Nb pers à charge'] = np.where(
    df['Nb enfants'] > df['Nb pers à charge'],  # Condition
    df['Nb enfants'],  # If True, update 'Nb pers à charge' with 'Nb enfants'
    df['Nb pers à charge']  # If False, keep the original value
)
df.drop(columns=['Nb enfants'], inplace=True)
print(df['Nb pers à charge'].unique())
# handle the 'Profession du mari' column
df['Profession du mari'] = df['Profession du mari'].apply(lambda x: 0 if x == 'non spécifié' else 1)
df['Profession du mari'] = df['Profession du mari'].astype(int)
print(df.head(10))
print(df.dtypes)
# Out:
# ['célibataire' 'mariée' 'non spécifié' 'divorcée' 'veuve' nan]
# [1 4 5 3 2 7 0]
#    Age  Situation maritale  Nb pers à charge  Profession du mari  Domicile  \
# 0   60                   0                 1                   0  monastir
# 1   46                   1                 1                   1  monastir
# 2   60                   1                 4                   1  monastir
# 3   48                   1                 5                   1  monastir
# 4   43                   1                 3                   1  monastir
# 5   50                   1                 5                   1  monastir
# 6   34                   0                 1                   0  monastir
# 7   33                   1                 3                   1  monastir
# 8   55                   1                 3                   1  monastir
# 9   52                   1                 2                   0  monastir
#
#   Niveau socio-économique     Tabagisme         Neffa Fumées de Tabouna  \
# 0            non spécifié           non           non               oui
# 1                     bon           non           non               oui
# 2            non spécifié           non           non               oui
# 3                   moyen           non           non               oui
# 4                     bon           non           non               oui
# 5            non spécifié  non spécifié  non spécifié      non spécifié
# 6                   moyen           non           non               non
# 7                   moyen           non           non               oui
# 8                     bas           non           non               oui
# 9                     bon           non           non               oui
#
#      Antécédents familiaux  ... Examen tête et cou Examen buccodentaire  \
# 0            cardiopathies  ...       non spécifié         non spécifié
# 1       hta, cardiopathies  ...       non spécifié         non spécifié
# 2                    aucun  ...       non spécifié         non spécifié
# 3             non spécifié  ...       non spécifié         non spécifié
# 4       hta, cardiopathies  ...       non spécifié         non spécifié
# 5             non spécifié  ...       non spécifié         non spécifié
# 6             hta, diabète  ...       non spécifié         non spécifié
# 7  diabète, tumeur maligne  ...       non spécifié         non spécifié
# 8             non spécifié  ...       non spécifié         non spécifié
# 9                      hta  ...       non spécifié         non spécifié
#
#   Examen des membres supérieurs                     Examen du rachis  \
# 0                  non spécifié                         non spécifié
# 1                  non spécifié                           lombalgies
# 2               douleurs coudes                         non spécifié
# 3                  non spécifié                         non spécifié
# 4                  non spécifié                     lombosciatalgies
# 5                  non spécifié       ncb droite - sciatalgie droite
# 6                  non spécifié  douleur palpation processus épineux
# 7                  non spécifié                         non spécifié
# 8                  non spécifié                         non spécifié
# 9                  non spécifié                         non spécifié
#
#   Examen des téguments Examen neurologique          Examen abdominal  \
# 0         non spécifié        non spécifié              non spécifié
# 1         non spécifié        non spécifié              non spécifié
# 2         non spécifié        non spécifié              non spécifié
# 3         non spécifié        non spécifié              non spécifié
# 4         non spécifié        non spécifié              non spécifié
# 5         non spécifié        non spécifié              non spécifié
# 6         non spécifié        non spécifié              non spécifié
# 7         non spécifié        non spécifié              non spécifié
# 8         non spécifié        non spécifié  sensibilité épigastrique
# 9         non spécifié        non spécifié              non spécifié
#
#                        Examen visuel         Spirométrie Interprétation Spiro
# 0                       non spécifié  mauvaise exécution                    -
# 1  pterygion bilatéral - flou visuel           non faite                    -
# 2                        flou visuel       interprétable                    -
# 3                                bav           non faite                    -
# 4                    pterygion droit       interprétable              normale
# 5                       non spécifié           non faite                    -
# 6                       non spécifié           non faite                    -
# 7                             myopie       interprétable              normale
# 8                       non spécifié           non faite                    -
# 9                       non spécifié       interprétable              normale
#
# [10 rows x 55 columns]
# Age                                        int64
# Situation maritale                         int64
# Nb pers à charge                           int64
# Profession du mari                         int64
# Domicile                                  object
# Niveau socio-économique                   object
# Tabagisme                                 object
# Neffa                                     object
# Fumées de Tabouna                         object
# Antécédents familiaux                     object
# q                                         object
# Antécédent personnels: chirurgicaux       object
# AT en milieu agricole                     object
# H travail / jour                          object
# Mécanisme AT                              object
# Ménopause                                 object
# Ancienneté agricole                       object
# Produits chimiques utilisés               object
# Troubles gynécologiques                   object
# Professions antérieures                   object
# Catégorie professionnelle                 object
# Statut                                    object
# Tâches effectuées                         object
# Contraintes physiques                     object
# Engrais utilisés                          object
# Produits biologiques utilisés             object
# Contraintes thermiques                    object
# J travail / Sem                           object
# Masque pour pesticides                    object
# Bottes                                    object
# Gants                                     object
# Casquette/Mdhalla                         object
# Manteau imperméable                       object
# Moyen de transport                        object
# Troubles cardio-respiratoires             object
# Troubles cognitifs                        object
# Troubles neurologiques                    object
# Troubles cutanés/phanères                 object
# Autres plaintes:                          object
# Poids                                    float64
# Taille                                   float64
# TAS                                      float64
# TAD                                      float64
# GAD                                       object
# Examen cardiovasculaire et pulmonaire     object
# Examen tête et cou                        object
# Examen buccodentaire                      object
# Examen des membres supérieurs             object
# Examen du rachis                          object
# Examen des téguments                      object
# Examen neurologique                       object
# Examen abdominal                          object
# Examen visuel                             object
# Spirométrie                               object
# Interprétation Spiro                      object
# dtype: object

# %%
# Map categorical values to numerical encoding
socio_economic_mapping = {
    'bon': 2,
    'moyen': 1,
    'bas': 0,
    'non spécifié': np.nan  # Temporarily set to NaN for treatment
}

# Apply mapping
df['Niveau socio-économique'] = df['Niveau socio-économique'].map(socio_economic_mapping)

# Fill missing values with the most frequent (mode) value
df['Niveau socio-économique'].fillna(df['Niveau socio-économique'].mode()[0], inplace=True)

# Convert to integer
df['Niveau socio-économique'] = df['Niveau socio-économique'].astype(int)

# Check results
print(df['Niveau socio-économique'].unique())
print(df[['Niveau socio-économique']].head(10))  # Display first 10 rows
# Out:
# [1 2 0]
#    Niveau socio-économique
# 0                        1
# 1                        2
# 2                        1
# 3                        1
# 4                        2
# 5                        1
# 6                        1
# 7                        1
# 8                        0
# 9                        2
# <ipython-input-202-547e941b39c4>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Niveau socio-économique'].fillna(df['Niveau socio-économique'].mode()[0], inplace=True)

# %%
df['Domicile'].unique()
df['Domicile'] = df['Domicile'].fillna(df['Domicile'].mode()[0])  # Fill missing values with mode
df['Domicile'] = df['Domicile'].astype('category')  # Convert to categorical type

print(df['Tabagisme'].unique())
print(df['Neffa'].unique())
# Step 1: Replace missing values with 'non' (non user)
# Step 1: Replace missing values with 'non' (non user)
df['Tabagisme'] = df['Tabagisme'].replace(['non spécifié', np.nan], 'non')
df['Tabagisme'] = df['Tabagisme'].replace(['passif', np.nan], 'oui')
df['Neffa'] = df['Neffa'].replace(['non spécifié', np.nan], 'non')

# Step 2: Convert to binary (1 for 'oui', 0 for 'non')
df['Tabagisme'] = df['Tabagisme'].map({'oui': 1, 'non': 0})
df['Neffa'] = df['Neffa'].map({'oui': 1, 'non': 0})

# Step 3: Create a new column 'TobaccoUse' that combines both columns
# Ensure there are no non-binary values in the columns
df['TobaccoUse'] = ((df['Tabagisme'] == 1) | (df['Neffa'] == 1)).astype(int)

# Drop the old columns if no longer needed
df.drop(columns=['Tabagisme', 'Neffa'], inplace=True)
#print(df.dtypes)
df['Fumées de Tabouna'] = df['Fumées de Tabouna'].replace(['non spécifié', np.nan], 'non')
df['Fumées de Tabouna'] = df['Fumées de Tabouna'].map({'oui': 1, 'non': 0})
df.head(20)
# Out:
# ['non' 'non spécifié' 'passif' 'oui' nan]
# ['non' 'non spécifié' nan]
#     Age  Situation maritale  Nb pers à charge  Profession du mari  Domicile  \
# 0    60                   0                 1                   0  monastir
# 1    46                   1                 1                   1  monastir
# 2    60                   1                 4                   1  monastir
# 3    48                   1                 5                   1  monastir
# 4    43                   1                 3                   1  monastir
# 5    50                   1                 5                   1  monastir
# 6    34                   0                 1                   0  monastir
# 7    33                   1                 3                   1  monastir
# 8    55                   1                 3                   1  monastir
# 9    52                   1                 2                   0  monastir
# 10   43                   1                 4                   1  monastir
# 11   52                   1                 4                   1  monastir
# 12   61                   1                 3                   1  monastir
# 13   58                   0                 1                   0  monastir
# 14   30                   1                 2                   1  monastir
# 15   56                   1                 4                   1  monastir
# 16   63                   0                 1                   0  monastir
# 17   66                   1                 1                   1  monastir
# 18   47                   1                 4                   1  monastir
# 19   48                   1                 3                   1  monastir
#
#     Niveau socio-économique  Fumées de Tabouna        Antécédents familiaux  \
# 0                         1                  1                cardiopathies
# 1                         2                  1           hta, cardiopathies
# 2                         1                  1                        aucun
# 3                         1                  1                 non spécifié
# 4                         2                  1           hta, cardiopathies
# 5                         1                  0                 non spécifié
# 6                         1                  0                 hta, diabète
# 7                         1                  1      diabète, tumeur maligne
# 8                         0                  1                 non spécifié
# 9                         2                  1                          hta
# 10                        1                  1                 non spécifié
# 11                        1                  1               tumeur maligne
# 12                        2                  1  hta, diabète, hypothyroidie
# 13                        1                  1                 non spécifié
# 14                        1                  1                hypothyroidie
# 15                        2                  1                        aucun
# 16                        1                  1               tumeur maligne
# 17                        0                  1                        aucun
# 18                        1                  1                 non spécifié
# 19                        1                  1                 non spécifié
#
#                                       q Antécédent personnels: chirurgicaux  \
# 0                          cardiopathie                               aucun
# 1                     hta, cardiopathie                césarienne, fracture
# 2                                 aucun                           cataracte
# 3                  infections génitales             césarienne, genou droit
# 4            asthme allergique, varices                          césarienne
# 5                          dyslipidémie                        non spécifié
# 6   gonarthrose - lombosciatique gauche                               aucun
# 7                                 aucun                          césarienne
# 8                            rhumatisme                          césarienne
# 9                                 aucun                 hernie discale l4l5
# 10                                  ncb                          césarienne
# 11                                aucun                               aucun
# 12          cardiopathie, hypothyroidie        cholecystectomie, césarienne
# 13              tendinite poignet droit                     appendicectomie
# 14                               anémie        cholecystectomie, césarienne
# 15                                aucun                          césarienne
# 16                           rhumatisme                               aucun
# 17                                aucun                               aucun
# 18                              diabète                          césarienne
# 19                              diabète                               aucun
#
#     ...     Examen buccodentaire Examen des membres supérieurs  \
# 0   ...             non spécifié                  non spécifié
# 1   ...             non spécifié                  non spécifié
# 2   ...             non spécifié               douleurs coudes
# 3   ...             non spécifié                  non spécifié
# 4   ...             non spécifié                  non spécifié
# 5   ...             non spécifié                  non spécifié
# 6   ...             non spécifié                  non spécifié
# 7   ...             non spécifié                  non spécifié
# 8   ...             non spécifié                  non spécifié
# 9   ...             non spécifié                  non spécifié
# 10  ...             non spécifié                  non spécifié
# 11  ...             non spécifié                  non spécifié
# 12  ...             non spécifié                  non spécifié
# 13  ...             non spécifié                  non spécifié
# 14  ...             non spécifié                  non spécifié
# 15  ...             non spécifié                  non spécifié
# 16  ...             non spécifié                  non spécifié
# 17  ...             non spécifié                  non spécifié
# 18  ...  tuméfaction sublinguale                  non spécifié
# 19  ...             non spécifié                  non spécifié
#
#                        Examen du rachis Examen des téguments  \
# 0                          non spécifié         non spécifié
# 1                            lombalgies         non spécifié
# 2                          non spécifié         non spécifié
# 3                          non spécifié         non spécifié
# 4                      lombosciatalgies         non spécifié
# 5        ncb droite - sciatalgie droite         non spécifié
# 6   douleur palpation processus épineux         non spécifié
# 7                          non spécifié         non spécifié
# 8                          non spécifié         non spécifié
# 9                          non spécifié         non spécifié
# 10                         non spécifié         non spécifié
# 11                         non spécifié         non spécifié
# 12                         non spécifié         non spécifié
# 13                         non spécifié         non spécifié
# 14                         non spécifié         non spécifié
# 15                         non spécifié         non spécifié
# 16                         non spécifié         non spécifié
# 17                         non spécifié         non spécifié
# 18                         non spécifié         non spécifié
# 19                         non spécifié         non spécifié
#
#    Examen neurologique          Examen abdominal  \
# 0         non spécifié              non spécifié
# 1         non spécifié              non spécifié
# 2         non spécifié              non spécifié
# 3         non spécifié              non spécifié
# 4         non spécifié              non spécifié
# 5         non spécifié              non spécifié
# 6         non spécifié              non spécifié
# 7         non spécifié              non spécifié
# 8         non spécifié  sensibilité épigastrique
# 9         non spécifié              non spécifié
# 10        non spécifié  sensibilité épigastrique
# 11        non spécifié              non spécifié
# 12        non spécifié              non spécifié
# 13        non spécifié              non spécifié
# 14        non spécifié              non spécifié
# 15        non spécifié              non spécifié
# 16        non spécifié              non spécifié
# 17        non spécifié              non spécifié
# 18        non spécifié              non spécifié
# 19        non spécifié              non spécifié
#
#                         Examen visuel         Spirométrie  \
# 0                        non spécifié  mauvaise exécution
# 1   pterygion bilatéral - flou visuel           non faite
# 2                         flou visuel       interprétable
# 3                                 bav           non faite
# 4                     pterygion droit       interprétable
# 5                        non spécifié           non faite
# 6                        non spécifié           non faite
# 7                              myopie       interprétable
# 8                        non spécifié           non faite
# 9                        non spécifié       interprétable
# 10                        flou visuel       interprétable
# 11                        flou visuel           non faite
# 12                       non spécifié           non faite
# 13                       non spécifié           non faite
# 14                       non spécifié           non faite
# 15                       non spécifié           non faite
# 16                        flou visuel           non faite
# 17                       non spécifié  mauvaise exécution
# 18                       non spécifié  mauvaise exécution
# 19                       non spécifié  mauvaise exécution
#
#    Interprétation Spiro TobaccoUse
# 0                     -          0
# 1                     -          0
# 2                     -          0
# 3                     -          0
# 4               normale          0
# 5                     -          0
# 6                     -          0
# 7               normale          0
# 8                     -          0
# 9               normale          0
# 10              normale          0
# 11                    -          0
# 12                    -          0
# 13                    -          0
# 14                    -          0
# 15                    -          0
# 16                    -          0
# 17                    -          0
# 18                    -          0
# 19                    -          1
#
# [20 rows x 54 columns]
